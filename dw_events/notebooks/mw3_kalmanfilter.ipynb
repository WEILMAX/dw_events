# %%
# %load_ext autoreload
# %autoreload 2

# %%
# Imports
import os
import pandas as pd
from dw_events.temperature_compensation.kalman_filter import KalmanFilter
from dw_events.data.make_dataset import DataGetter
from dw_events.data.utils import make_dt_list, get_dataframe_str_subset
import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
start = datetime.datetime(2022, 9, 1)
end = datetime.datetime(2022, 9, 2)
data_path = \
    "_".join(
        [
            "../data/raw/strain_data",
            str(start.year),
            str(start.month),
            str(start.day),
            str(end.year),
            str(end.month),
            str(end.day),
            ".parquet"
        ]
    )
datagetter = DataGetter(start, end)
try:
    strain_data = pd.read_parquet(data_path)
    datagetter.merged_signals = strain_data
except:
    strain_data = datagetter.get_strain_data()
    strain_data.to_parquet(data_path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Max\Documents\OWI_LAB\Code\Packages\dw_events\dw_events\notebooks\mw3_kalmanfilter.ipynb Cell 3 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#W2sZmlsZQ%3D%3D?line=16'>17</a> try:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#W2sZmlsZQ%3D%3D?line=17'>18</a>     strain_data = pd.read_parquet(data_path)
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#W2sZmlsZQ%3D%3D?line=18'>19</a>     datagetter.merged_signals = strain_data
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\io\parquet.py:493, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     491 impl = get_engine(engine)
# --> 493 return impl.read(
#     494     path,
#     495     columns=columns,
#     496     storage_options=storage_options,
#     497     use_nullable_dtypes=use_nullable_dtypes,
#     498     **kwargs,
#     499 )
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\io\parquet.py:240, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     239 try:
# --> 240     result = self.api.parquet.read_table(
#     241         path_or_handle, columns=columns, **kwargs
#     242     ).to_pandas(**to_pandas_kwargs)
#     243     if manager == "array":
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\parquet.py:1700, in read_table(source, columns, use_threads, metadata, use_pandas_metadata, memory_map, read_dictionary, filesystem, filters, buffer_size, partitioning, use_legacy_dataset, ignore_prefixes)
#    1699 try:
# -> 1700     dataset = _ParquetDatasetV2(
#    1701         source,
#    1702         filesystem=filesystem,
#    1703         partitioning=partitioning,
#    1704         memory_map=memory_map,
#    1705         read_dictionary=read_dictionary,
#    1706         buffer_size=buffer_size,
#    1707         filters=filters,
#    1708         ignore_prefixes=ignore_prefixes,
#    1709     )
#    1710 except ImportError:
#    1711     # fall back on ParquetFile for simple cases when pyarrow.dataset
#    1712     # module is not available
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\parquet.py:1543, in _ParquetDatasetV2.__init__(self, path_or_paths, filesystem, filters, partitioning, read_dictionary, buffer_size, memory_map, ignore_prefixes, **kwargs)
#    1540 fragment = parquet_format.make_fragment(single_file, filesystem)
#    1542 self._dataset = ds.FileSystemDataset(
# -> 1543     [fragment], schema=fragment.physical_schema,
#    1544     format=parquet_format,
#    1545     filesystem=fragment.filesystem
#    1546 )
#    1547 return
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\_dataset.pyx:911, in pyarrow._dataset.Fragment.physical_schema.__get__()
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\error.pxi:141, in pyarrow.lib.pyarrow_internal_check_status()
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\error.pxi:112, in pyarrow.lib.check_status()
#
# OSError: Could not open parquet input source '<Buffer>': Invalid: Parquet file size is 4 bytes, smaller than the minimum file footer (8 bytes)
#
# During handling of the above exception, another exception occurred:
#
# ArrowNotImplementedError                  Traceback (most recent call last)
# c:\Users\Max\Documents\OWI_LAB\Code\Packages\dw_events\dw_events\notebooks\mw3_kalmanfilter.ipynb Cell 3 in <cell line: 17>()
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#W2sZmlsZQ%3D%3D?line=19'>20</a> except:
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#W2sZmlsZQ%3D%3D?line=20'>21</a>     strain_data = datagetter.get_strain_data()
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#W2sZmlsZQ%3D%3D?line=21'>22</a>     strain_data.to_parquet(data_path)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\frame.py:2835, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2749 """
#    2750 Write a DataFrame to the binary parquet format.
#    2751
#    (...)
#    2831 >>> content = f.read()
#    2832 """
#    2833 from pandas.io.parquet import to_parquet
# -> 2835 return to_parquet(
#    2836     self,
#    2837     path,
#    2838     engine,
#    2839     compression=compression,
#    2840     index=index,
#    2841     partition_cols=partition_cols,
#    2842     storage_options=storage_options,
#    2843     **kwargs,
#    2844 )
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\io\parquet.py:420, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, **kwargs)
#     416 impl = get_engine(engine)
#     418 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 420 impl.write(
#     421     df,
#     422     path_or_buf,
#     423     compression=compression,
#     424     index=index,
#     425     partition_cols=partition_cols,
#     426     storage_options=storage_options,
#     427     **kwargs,
#     428 )
#     430 if path is None:
#     431     assert isinstance(path_or_buf, io.BytesIO)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\io\parquet.py:195, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, **kwargs)
#     186         self.api.parquet.write_to_dataset(
#     187             table,
#     188             path_or_handle,
#    (...)
#     191             **kwargs,
#     192         )
#     193     else:
#     194         # write to single output file
# --> 195         self.api.parquet.write_table(
#     196             table, path_or_handle, compression=compression, **kwargs
#     197         )
#     198 finally:
#     199     if handles is not None:
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\parquet.py:1817, in write_table(table, where, row_group_size, version, use_dictionary, compression, write_statistics, use_deprecated_int96_timestamps, coerce_timestamps, allow_truncated_timestamps, data_page_size, flavor, filesystem, compression_level, use_byte_stream_split, data_page_version, use_compliant_nested_type, **kwargs)
#    1799 try:
#    1800     with ParquetWriter(
#    1801             where, table.schema,
#    1802             filesystem=filesystem,
#    (...)
#    1815             use_compliant_nested_type=use_compliant_nested_type,
#    1816             **kwargs) as writer:
# -> 1817         writer.write_table(table, row_group_size=row_group_size)
#    1818 except Exception:
#    1819     if _is_path_like(where):
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\parquet.py:677, in ParquetWriter.write_table(self, table, row_group_size)
#     672     msg = ('Table schema does not match schema used to create file: '
#     673            '\ntable:\n{!s} vs. \nfile:\n{!s}'
#     674            .format(table.schema, self.schema))
#     675     raise ValueError(msg)
# --> 677 self.writer.write_table(table, row_group_size=row_group_size)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\_parquet.pyx:1420, in pyarrow._parquet.ParquetWriter.write_table()
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pyarrow\error.pxi:118, in pyarrow.lib.check_status()
#
# ArrowNotImplementedError: Support for codec 'snappy' not built

# %%
# Get strain line data BCN
BCN_signals = datagetter.get_dataframe_str_subset('BCN')
# Temperature data
temperature_data = datagetter.get_dataframe_str_subset('TFBG')
bottom_temperature_data = temperature_data.filter(regex="_B")
delta_bottom_temperature_data = bottom_temperature_data - bottom_temperature_data.shift(1)

# %%
start = 990000
stop = 1000000

measurements = BCN_signals[~BCN_signals.index.duplicated(keep='first')].iloc[start:stop]
inputs = delta_bottom_temperature_data[~delta_bottom_temperature_data.index.duplicated(keep='first')].iloc[start:stop]

process_variance =  1e-4 * np.eye(BCN_signals.shape[1])
estimated_measurement_variance = 1000 * np.eye(BCN_signals.shape[1])

kf = \
    KalmanFilter(
        process_variance,
        estimated_measurement_variance,
        measurements.iloc[0].values,
        np.eye(BCN_signals.shape[1])
    )
compensated_data = kf.apply_filter(measurements, inputs)
filtered_data = kf.filtered_data

# %%
# Plot the combined portfolio
plt.figure(figsize=(20,5))
plt.plot(measurements)
plt.plot(filtered_data)
plt.show()
# Plot the combined portfolio
plt.figure(figsize=(20,5))
plt.plot(compensated_data)
plt.show()

# %% [markdown]
# ## Try proximity rule through A matrix

# %%
a_matrix = \
    np.array(
        [
            np.array([0.99, 0.01, 0, 0, 0, 0, 0]),
            np.array([0.01, 0.98, 0.01, 0, 0, 0, 0]),
            np.array([0, 0.01, 0.98, 0.01, 0, 0, 0]),
            np.array([0, 0, 0.01, 0.98, 0.01, 0, 0]),
            np.array([0, 0, 0, 0.01, 0.98, 0.01, 0]),
            np.array([0, 0, 0, 0, 0.01, 0.98, 0.01]),
            np.array([0, 0, 0, 0, 0, 0.01, 0.99])
        ]
        )

# %%
start = 990000
stop = 1000000

measurements = BCN_signals[~BCN_signals.index.duplicated(keep='first')].iloc[start:stop]
inputs = delta_bottom_temperature_data[~delta_bottom_temperature_data.index.duplicated(keep='first')].iloc[start:stop]

process_variance =  1e-4 * np.eye(BCN_signals.shape[1])
estimated_measurement_variance = 10000 * np.eye(BCN_signals.shape[1])

kf = \
    KalmanFilter(
        process_variance,
        estimated_measurement_variance,
        measurements.iloc[0].values,
        np.eye(BCN_signals.shape[1]),
        a_matrix = a_matrix,
        c_matrix = a_matrix
    )
compensated_data = kf.apply_filter(measurements, inputs)
filtered_data = kf.filtered_data
# Out:
# c:\users\max\documents\owi_lab\code\packages\dw_events\dw_events\dw_events\temperature_compensation\kalman_filter.py:145: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   if self.a_matrix != (measurements_data.shape[1], measurements_data.shape[1]):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:362, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:570, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: Unknown datetime string format, unable to parse: SCB_ALM_BCN_FBG_HOR002_0_nr1
#
# During handling of the above exception, another exception occurred:
#
# DateParseError                            Traceback (most recent call last)
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\indexes\datetimes.py:644, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     643 try:
# --> 644     parsed, reso = self._parse_with_reso(key)
#     645 except ValueError as err:
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\indexes\datetimelike.py:231, in DatetimeIndexOpsMixin._parse_with_reso(self, label)
#     229 def _parse_with_reso(self, label: str):
#     230     # overridden by TimedeltaIndex
# --> 231     parsed, reso_str = parsing.parse_time_string(label, self.freq)
#     232     reso = Resolution.from_attrname(reso_str)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:321, in pandas._libs.tslibs.parsing.parse_time_string()
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:367, in pandas._libs.tslibs.parsing.parse_datetime_string_with_reso()
#
# DateParseError: Unknown datetime string format, unable to parse: SCB_ALM_BCN_FBG_HOR002_0_nr1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\Max\Documents\OWI_LAB\Code\Packages\dw_events\dw_events\notebooks\mw3_kalmanfilter.ipynb Cell 9 in <cell line: 19>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=7'>8</a> estimated_measurement_variance = 10000 * np.eye(BCN_signals.shape[1])
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=9'>10</a> kf = \
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=10'>11</a>     KalmanFilter(
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=11'>12</a>         process_variance,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=16'>17</a>         c_matrix = a_matrix
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=17'>18</a>     )
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=18'>19</a> compensated_data = kf.apply_filter(measurements, inputs)
#      <a href='vscode-notebook-cell:/c%3A/Users/Max/Documents/OWI_LAB/Code/Packages/dw_events/dw_events/notebooks/mw3_kalmanfilter.ipynb#X31sZmlsZQ%3D%3D?line=19'>20</a> filtered_data = kf.filtered_data
#
# File c:\users\max\documents\owi_lab\code\packages\dw_events\dw_events\dw_events\temperature_compensation\kalman_filter.py:170, in KalmanFilter.apply_filter(self, measurements_data, input_data)
#     156 def apply_filter(
#     157     self,
#     158     measurements_data: pd.DataFrame,
#     159     input_data: pd.DataFrame
#     160     ) -> pd.DataFrame:
#     161     """Apply the kalman filter for
#     162     temperature compensation of the strain data.
#     163
#    (...)
#     168     pd.Series: The filtered strain data.
#     169     """
# --> 170     filtered_data = self.filter_data(measurements_data, input_data)
#     171     compensated_data = measurements_data - filtered_data
#     172     return compensated_data
#
# File c:\users\max\documents\owi_lab\code\packages\dw_events\dw_events\dw_events\temperature_compensation\kalman_filter.py:149, in KalmanFilter.filter_data(self, measurements_data, input_data)
#     145 filtered_data = pd.Series()
#     146 for index, row in measurements_data.iteritems():
#     147     self.input_latest_noisy_measurement(
#     148         row,
# --> 149         input_data.loc[index])
#     150     filtered_data.loc[index] = \
#     151         self.get_latest_estimated_measurement()
#     153 self.filtered_data = filtered_data
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# -> 1153     return self.obj.xs(label, axis=axis)
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\generic.py:3864, in NDFrame.xs(self, key, axis, level, drop_level)
#    3862             new_index = index[loc]
#    3863 else:
# -> 3864     loc = index.get_loc(key)
#    3866     if isinstance(loc, np.ndarray):
#    3867         if loc.dtype == np.bool_:
#
# File c:\Users\Max\anaconda3\envs\scb\lib\site-packages\pandas\core\indexes\datetimes.py:646, in DatetimeIndex.get_loc(self, key, method, tolerance)
#     644     parsed, reso = self._parse_with_reso(key)
#     645 except ValueError as err:
# --> 646     raise KeyError(key) from err
#     648 if self._can_partial_date_slice(reso):
#     649     try:
#
# KeyError: 'SCB_ALM_BCN_FBG_HOR002_0_nr1'

# %%
# Plot the combined portfolio
plt.figure(figsize=(20,5))
plt.plot(measurements)
plt.plot(filtered_data)
plt.show()
# Plot the combined portfolio
plt.figure(figsize=(20,5))
plt.plot(compensated_data)
plt.show()
